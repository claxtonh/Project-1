# %%
# %matplotlib inline
import requests
import json
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np

base_url = "http://dnd5eapi.co/api/"

# %% [markdown]
# ## Monsters

# %%
monster_url = base_url + "monsters"
print(monster_url)
# Out:
# http://dnd5eapi.co/api/monsters

# %%
monster_names = requests.get(monster_url).json()
monster_names
# Out:
# {'count': 325,
#  'results': [{'name': 'Aboleth',
#    'url': 'http://www.dnd5eapi.co/api/monsters/1'},
#   {'name': 'Acolyte', 'url': 'http://www.dnd5eapi.co/api/monsters/2'},
#   {'name': 'Adult Black Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/3'},
#   {'name': 'Adult Blue Dracolich',
#    'url': 'http://www.dnd5eapi.co/api/monsters/4'},
#   {'name': 'Adult Blue Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/5'},
#   {'name': 'Adult Brass Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/6'},
#   {'name': 'Adult Bronze Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/7'},
#   {'name': 'Adult Copper Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/8'},
#   {'name': 'Adult Gold Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/9'},
#   {'name': 'Adult Green Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/10'},
#   {'name': 'Adult Red Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/11'},
#   {'name': 'Adult Silver Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/12'},
#   {'name': 'Adult White Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/13'},
#   {'name': 'Air Elemental', 'url': 'http://www.dnd5eapi.co/api/monsters/14'},
#   {'name': 'Ancient Black Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/15'},
#   {'name': 'Ancient Blue Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/16'},
#   {'name': 'Ancient Brass Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/17'},
#   {'name': 'Ancient Bronze Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/18'},
#   {'name': 'Ancient Copper Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/19'},
#   {'name': 'Ancient Gold Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/20'},
#   {'name': 'Ancient Green Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/21'},
#   {'name': 'Ancient Red Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/22'},
#   {'name': 'Ancient Silver Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/23'},
#   {'name': 'Ancient White Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/24'},
#   {'name': 'Androsphinx', 'url': 'http://www.dnd5eapi.co/api/monsters/25'},
#   {'name': 'Animated Armor', 'url': 'http://www.dnd5eapi.co/api/monsters/26'},
#   {'name': 'Ankheg', 'url': 'http://www.dnd5eapi.co/api/monsters/27'},
#   {'name': 'Ape', 'url': 'http://www.dnd5eapi.co/api/monsters/28'},
#   {'name': 'Archmage', 'url': 'http://www.dnd5eapi.co/api/monsters/29'},
#   {'name': 'Assassin', 'url': 'http://www.dnd5eapi.co/api/monsters/30'},
#   {'name': 'Awakened Shrub', 'url': 'http://www.dnd5eapi.co/api/monsters/31'},
#   {'name': 'Awakened Tree', 'url': 'http://www.dnd5eapi.co/api/monsters/32'},
#   {'name': 'Axe Beak', 'url': 'http://www.dnd5eapi.co/api/monsters/33'},
#   {'name': 'Azer', 'url': 'http://www.dnd5eapi.co/api/monsters/34'},
#   {'name': 'Baboon', 'url': 'http://www.dnd5eapi.co/api/monsters/35'},
#   {'name': 'Badger', 'url': 'http://www.dnd5eapi.co/api/monsters/36'},
#   {'name': 'Balor', 'url': 'http://www.dnd5eapi.co/api/monsters/37'},
#   {'name': 'Bandit', 'url': 'http://www.dnd5eapi.co/api/monsters/38'},
#   {'name': 'Bandit Captain', 'url': 'http://www.dnd5eapi.co/api/monsters/39'},
#   {'name': 'Barbed Devil', 'url': 'http://www.dnd5eapi.co/api/monsters/40'},
#   {'name': 'Basilisk', 'url': 'http://www.dnd5eapi.co/api/monsters/41'},
#   {'name': 'Bat', 'url': 'http://www.dnd5eapi.co/api/monsters/42'},
#   {'name': 'Bearded Devil', 'url': 'http://www.dnd5eapi.co/api/monsters/43'},
#   {'name': 'Behir', 'url': 'http://www.dnd5eapi.co/api/monsters/44'},
#   {'name': 'Berserker', 'url': 'http://www.dnd5eapi.co/api/monsters/45'},
#   {'name': 'Black Bear', 'url': 'http://www.dnd5eapi.co/api/monsters/46'},
#   {'name': 'Black Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/47'},
#   {'name': 'Black Pudding', 'url': 'http://www.dnd5eapi.co/api/monsters/48'},
#   {'name': 'Blink Dog', 'url': 'http://www.dnd5eapi.co/api/monsters/49'},
#   {'name': 'Blood Hawk', 'url': 'http://www.dnd5eapi.co/api/monsters/50'},
#   {'name': 'Blue Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/51'},
#   {'name': 'Boar', 'url': 'http://www.dnd5eapi.co/api/monsters/52'},
#   {'name': 'Bone Devil', 'url': 'http://www.dnd5eapi.co/api/monsters/53'},
#   {'name': 'Brass Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/54'},
#   {'name': 'Bronze Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/55'},
#   {'name': 'Brown Bear', 'url': 'http://www.dnd5eapi.co/api/monsters/56'},
#   {'name': 'Bugbear', 'url': 'http://www.dnd5eapi.co/api/monsters/57'},
#   {'name': 'Bulette', 'url': 'http://www.dnd5eapi.co/api/monsters/58'},
#   {'name': 'Camel', 'url': 'http://www.dnd5eapi.co/api/monsters/59'},
#   {'name': 'Carrion Crawler', 'url': 'http://www.dnd5eapi.co/api/monsters/60'},
#   {'name': 'Cat', 'url': 'http://www.dnd5eapi.co/api/monsters/61'},
#   {'name': 'Cave Bear', 'url': 'http://www.dnd5eapi.co/api/monsters/62'},
#   {'name': 'Centaur', 'url': 'http://www.dnd5eapi.co/api/monsters/63'},
#   {'name': 'Chain Devil', 'url': 'http://www.dnd5eapi.co/api/monsters/64'},
#   {'name': 'Chimera', 'url': 'http://www.dnd5eapi.co/api/monsters/65'},
#   {'name': 'Chuul', 'url': 'http://www.dnd5eapi.co/api/monsters/66'},
#   {'name': 'Clay Golem', 'url': 'http://www.dnd5eapi.co/api/monsters/67'},
#   {'name': 'Cloaker', 'url': 'http://www.dnd5eapi.co/api/monsters/68'},
#   {'name': 'Cloud Giant', 'url': 'http://www.dnd5eapi.co/api/monsters/69'},
#   {'name': 'Cockatrice', 'url': 'http://www.dnd5eapi.co/api/monsters/70'},
#   {'name': 'Commoner', 'url': 'http://www.dnd5eapi.co/api/monsters/71'},
#   {'name': 'Constrictor Snake',
#    'url': 'http://www.dnd5eapi.co/api/monsters/72'},
#   {'name': 'Copper Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/73'},
#   {'name': 'Couatl', 'url': 'http://www.dnd5eapi.co/api/monsters/74'},
#   {'name': 'Crab', 'url': 'http://www.dnd5eapi.co/api/monsters/75'},
#   {'name': 'Crocodile', 'url': 'http://www.dnd5eapi.co/api/monsters/76'},
#   {'name': 'Cult Fanatic', 'url': 'http://www.dnd5eapi.co/api/monsters/77'},
#   {'name': 'Cultist', 'url': 'http://www.dnd5eapi.co/api/monsters/78'},
#   {'name': 'Darkmantle', 'url': 'http://www.dnd5eapi.co/api/monsters/79'},
#   {'name': 'Death Dog', 'url': 'http://www.dnd5eapi.co/api/monsters/80'},
#   {'name': 'Deep Gnome (Svirfneblin)',
#    'url': 'http://www.dnd5eapi.co/api/monsters/81'},
#   {'name': 'Deer', 'url': 'http://www.dnd5eapi.co/api/monsters/82'},
#   {'name': 'Deva', 'url': 'http://www.dnd5eapi.co/api/monsters/83'},
#   {'name': 'Dire Wolf', 'url': 'http://www.dnd5eapi.co/api/monsters/84'},
#   {'name': 'Djinni', 'url': 'http://www.dnd5eapi.co/api/monsters/85'},
#   {'name': 'Doppelganger', 'url': 'http://www.dnd5eapi.co/api/monsters/86'},
#   {'name': 'Draft Horse', 'url': 'http://www.dnd5eapi.co/api/monsters/87'},
#   {'name': 'Dragon Turtle', 'url': 'http://www.dnd5eapi.co/api/monsters/88'},
#   {'name': 'Dretch', 'url': 'http://www.dnd5eapi.co/api/monsters/89'},
#   {'name': 'Drider', 'url': 'http://www.dnd5eapi.co/api/monsters/90'},
#   {'name': 'Drow', 'url': 'http://www.dnd5eapi.co/api/monsters/91'},
#   {'name': 'Druid', 'url': 'http://www.dnd5eapi.co/api/monsters/92'},
#   {'name': 'Dryad', 'url': 'http://www.dnd5eapi.co/api/monsters/93'},
#   {'name': 'Duergar', 'url': 'http://www.dnd5eapi.co/api/monsters/94'},
#   {'name': 'Dust Mephit', 'url': 'http://www.dnd5eapi.co/api/monsters/95'},
#   {'name': 'Eagle', 'url': 'http://www.dnd5eapi.co/api/monsters/96'},
#   {'name': 'Earth Elemental', 'url': 'http://www.dnd5eapi.co/api/monsters/97'},
#   {'name': 'Efreeti', 'url': 'http://www.dnd5eapi.co/api/monsters/98'},
#   {'name': 'Elephant', 'url': 'http://www.dnd5eapi.co/api/monsters/99'},
#   {'name': 'Elk', 'url': 'http://www.dnd5eapi.co/api/monsters/100'},
#   {'name': 'Erinyes', 'url': 'http://www.dnd5eapi.co/api/monsters/101'},
#   {'name': 'Ettercap', 'url': 'http://www.dnd5eapi.co/api/monsters/102'},
#   {'name': 'Ettin', 'url': 'http://www.dnd5eapi.co/api/monsters/103'},
#   {'name': 'Fire Elemental', 'url': 'http://www.dnd5eapi.co/api/monsters/104'},
#   {'name': 'Fire Giant', 'url': 'http://www.dnd5eapi.co/api/monsters/105'},
#   {'name': 'Flesh Golem', 'url': 'http://www.dnd5eapi.co/api/monsters/106'},
#   {'name': 'Flying Snake', 'url': 'http://www.dnd5eapi.co/api/monsters/107'},
#   {'name': 'Flying Sword', 'url': 'http://www.dnd5eapi.co/api/monsters/108'},
#   {'name': 'Frog', 'url': 'http://www.dnd5eapi.co/api/monsters/109'},
#   {'name': 'Frost Giant', 'url': 'http://www.dnd5eapi.co/api/monsters/110'},
#   {'name': 'Gargoyle', 'url': 'http://www.dnd5eapi.co/api/monsters/111'},
#   {'name': 'Gelatinous Cube',
#    'url': 'http://www.dnd5eapi.co/api/monsters/112'},
#   {'name': 'Ghast', 'url': 'http://www.dnd5eapi.co/api/monsters/113'},
#   {'name': 'Ghost', 'url': 'http://www.dnd5eapi.co/api/monsters/114'},
#   {'name': 'Ghoul', 'url': 'http://www.dnd5eapi.co/api/monsters/115'},
#   {'name': 'Giant Ape', 'url': 'http://www.dnd5eapi.co/api/monsters/116'},
#   {'name': 'Giant Badger', 'url': 'http://www.dnd5eapi.co/api/monsters/117'},
#   {'name': 'Giant Bat', 'url': 'http://www.dnd5eapi.co/api/monsters/118'},
#   {'name': 'Giant Boar', 'url': 'http://www.dnd5eapi.co/api/monsters/119'},
#   {'name': 'Giant Centipede',
#    'url': 'http://www.dnd5eapi.co/api/monsters/120'},
#   {'name': 'Giant Constrictor Snake',
#    'url': 'http://www.dnd5eapi.co/api/monsters/121'},
#   {'name': 'Giant Crab', 'url': 'http://www.dnd5eapi.co/api/monsters/122'},
#   {'name': 'Giant Crocodile',
#    'url': 'http://www.dnd5eapi.co/api/monsters/123'},
#   {'name': 'Giant Eagle', 'url': 'http://www.dnd5eapi.co/api/monsters/124'},
#   {'name': 'Giant Elk', 'url': 'http://www.dnd5eapi.co/api/monsters/125'},
#   {'name': 'Giant Fire Beetle',
#    'url': 'http://www.dnd5eapi.co/api/monsters/126'},
#   {'name': 'Giant Frog', 'url': 'http://www.dnd5eapi.co/api/monsters/127'},
#   {'name': 'Giant Goat', 'url': 'http://www.dnd5eapi.co/api/monsters/128'},
#   {'name': 'Giant Hyena', 'url': 'http://www.dnd5eapi.co/api/monsters/129'},
#   {'name': 'Giant Lizard', 'url': 'http://www.dnd5eapi.co/api/monsters/130'},
#   {'name': 'Giant Octopus', 'url': 'http://www.dnd5eapi.co/api/monsters/131'},
#   {'name': 'Giant Owl', 'url': 'http://www.dnd5eapi.co/api/monsters/132'},
#   {'name': 'Giant Poisonous Snake',
#    'url': 'http://www.dnd5eapi.co/api/monsters/133'},
#   {'name': 'Giant Rat', 'url': 'http://www.dnd5eapi.co/api/monsters/134'},
#   {'name': 'Giant Rat (Diseased)',
#    'url': 'http://www.dnd5eapi.co/api/monsters/135'},
#   {'name': 'Giant Scorpion', 'url': 'http://www.dnd5eapi.co/api/monsters/136'},
#   {'name': 'Giant Sea Horse',
#    'url': 'http://www.dnd5eapi.co/api/monsters/137'},
#   {'name': 'Giant Shark', 'url': 'http://www.dnd5eapi.co/api/monsters/138'},
#   {'name': 'Giant Spider', 'url': 'http://www.dnd5eapi.co/api/monsters/139'},
#   {'name': 'Giant Toad', 'url': 'http://www.dnd5eapi.co/api/monsters/140'},
#   {'name': 'Giant Vulture', 'url': 'http://www.dnd5eapi.co/api/monsters/141'},
#   {'name': 'Giant Wasp', 'url': 'http://www.dnd5eapi.co/api/monsters/142'},
#   {'name': 'Giant Weasel', 'url': 'http://www.dnd5eapi.co/api/monsters/143'},
#   {'name': 'Giant Wolf Spider',
#    'url': 'http://www.dnd5eapi.co/api/monsters/144'},
#   {'name': 'Gibbering Mouther',
#    'url': 'http://www.dnd5eapi.co/api/monsters/145'},
#   {'name': 'Glabrezu', 'url': 'http://www.dnd5eapi.co/api/monsters/146'},
#   {'name': 'Gladiator', 'url': 'http://www.dnd5eapi.co/api/monsters/147'},
#   {'name': 'Gnoll', 'url': 'http://www.dnd5eapi.co/api/monsters/148'},
#   {'name': 'Goat', 'url': 'http://www.dnd5eapi.co/api/monsters/149'},
#   {'name': 'Goblin', 'url': 'http://www.dnd5eapi.co/api/monsters/150'},
#   {'name': 'Gold Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/151'},
#   {'name': 'Gorgon', 'url': 'http://www.dnd5eapi.co/api/monsters/152'},
#   {'name': 'Gray Ooze', 'url': 'http://www.dnd5eapi.co/api/monsters/153'},
#   {'name': 'Green Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/154'},
#   {'name': 'Green Hag', 'url': 'http://www.dnd5eapi.co/api/monsters/155'},
#   {'name': 'Grick', 'url': 'http://www.dnd5eapi.co/api/monsters/156'},
#   {'name': 'Griffon', 'url': 'http://www.dnd5eapi.co/api/monsters/157'},
#   {'name': 'Grimlock', 'url': 'http://www.dnd5eapi.co/api/monsters/158'},
#   {'name': 'Guard', 'url': 'http://www.dnd5eapi.co/api/monsters/159'},
#   {'name': 'Guardian Naga', 'url': 'http://www.dnd5eapi.co/api/monsters/160'},
#   {'name': 'Gynosphinx', 'url': 'http://www.dnd5eapi.co/api/monsters/161'},
#   {'name': 'Half-Red Dragon Veteran',
#    'url': 'http://www.dnd5eapi.co/api/monsters/162'},
#   {'name': 'Harpy', 'url': 'http://www.dnd5eapi.co/api/monsters/163'},
#   {'name': 'Hawk', 'url': 'http://www.dnd5eapi.co/api/monsters/164'},
#   {'name': 'Hell Hound', 'url': 'http://www.dnd5eapi.co/api/monsters/165'},
#   {'name': 'Hezrou', 'url': 'http://www.dnd5eapi.co/api/monsters/166'},
#   {'name': 'Hill Giant', 'url': 'http://www.dnd5eapi.co/api/monsters/167'},
#   {'name': 'Hippogriff', 'url': 'http://www.dnd5eapi.co/api/monsters/168'},
#   {'name': 'Hobgoblin', 'url': 'http://www.dnd5eapi.co/api/monsters/169'},
#   {'name': 'Homunculus', 'url': 'http://www.dnd5eapi.co/api/monsters/170'},
#   {'name': 'Horned Devil', 'url': 'http://www.dnd5eapi.co/api/monsters/171'},
#   {'name': 'Hunter Shark', 'url': 'http://www.dnd5eapi.co/api/monsters/172'},
#   {'name': 'Hydra', 'url': 'http://www.dnd5eapi.co/api/monsters/173'},
#   {'name': 'Hyena', 'url': 'http://www.dnd5eapi.co/api/monsters/174'},
#   {'name': 'Ice Devil', 'url': 'http://www.dnd5eapi.co/api/monsters/175'},
#   {'name': 'Ice Mephit', 'url': 'http://www.dnd5eapi.co/api/monsters/176'},
#   {'name': 'Imp', 'url': 'http://www.dnd5eapi.co/api/monsters/177'},
#   {'name': 'Invisible Stalker',
#    'url': 'http://www.dnd5eapi.co/api/monsters/178'},
#   {'name': 'Iron Golem', 'url': 'http://www.dnd5eapi.co/api/monsters/179'},
#   {'name': 'Jackal', 'url': 'http://www.dnd5eapi.co/api/monsters/180'},
#   {'name': 'Killer Whale', 'url': 'http://www.dnd5eapi.co/api/monsters/181'},
#   {'name': 'Knight', 'url': 'http://www.dnd5eapi.co/api/monsters/182'},
#   {'name': 'Kobold', 'url': 'http://www.dnd5eapi.co/api/monsters/183'},
#   {'name': 'Kraken', 'url': 'http://www.dnd5eapi.co/api/monsters/184'},
#   {'name': 'Lamia', 'url': 'http://www.dnd5eapi.co/api/monsters/185'},
#   {'name': 'Lemure', 'url': 'http://www.dnd5eapi.co/api/monsters/186'},
#   {'name': 'Lich', 'url': 'http://www.dnd5eapi.co/api/monsters/187'},
#   {'name': 'Lion', 'url': 'http://www.dnd5eapi.co/api/monsters/188'},
#   {'name': 'Lizard', 'url': 'http://www.dnd5eapi.co/api/monsters/189'},
#   {'name': 'Lizardfolk', 'url': 'http://www.dnd5eapi.co/api/monsters/190'},
#   {'name': 'Mage', 'url': 'http://www.dnd5eapi.co/api/monsters/191'},
#   {'name': 'Magma Mephit', 'url': 'http://www.dnd5eapi.co/api/monsters/192'},
#   {'name': 'Magmin', 'url': 'http://www.dnd5eapi.co/api/monsters/193'},
#   {'name': 'Mammoth', 'url': 'http://www.dnd5eapi.co/api/monsters/194'},
#   {'name': 'Manticore', 'url': 'http://www.dnd5eapi.co/api/monsters/195'},
#   {'name': 'Marilith', 'url': 'http://www.dnd5eapi.co/api/monsters/196'},
#   {'name': 'Mastiff', 'url': 'http://www.dnd5eapi.co/api/monsters/197'},
#   {'name': 'Medusa', 'url': 'http://www.dnd5eapi.co/api/monsters/198'},
#   {'name': 'Merfolk', 'url': 'http://www.dnd5eapi.co/api/monsters/199'},
#   {'name': 'Merrow', 'url': 'http://www.dnd5eapi.co/api/monsters/200'},
#   {'name': 'Mimic', 'url': 'http://www.dnd5eapi.co/api/monsters/201'},
#   {'name': 'Minotaur', 'url': 'http://www.dnd5eapi.co/api/monsters/202'},
#   {'name': 'Minotaur Skeleton',
#    'url': 'http://www.dnd5eapi.co/api/monsters/203'},
#   {'name': 'Mule', 'url': 'http://www.dnd5eapi.co/api/monsters/204'},
#   {'name': 'Mummy', 'url': 'http://www.dnd5eapi.co/api/monsters/205'},
#   {'name': 'Mummy Lord', 'url': 'http://www.dnd5eapi.co/api/monsters/206'},
#   {'name': 'Nalfeshnee', 'url': 'http://www.dnd5eapi.co/api/monsters/207'},
#   {'name': 'Night Hag', 'url': 'http://www.dnd5eapi.co/api/monsters/208'},
#   {'name': 'Nightmare', 'url': 'http://www.dnd5eapi.co/api/monsters/209'},
#   {'name': 'Noble', 'url': 'http://www.dnd5eapi.co/api/monsters/210'},
#   {'name': 'Ochre Jelly', 'url': 'http://www.dnd5eapi.co/api/monsters/211'},
#   {'name': 'Octopus', 'url': 'http://www.dnd5eapi.co/api/monsters/212'},
#   {'name': 'Ogre', 'url': 'http://www.dnd5eapi.co/api/monsters/213'},
#   {'name': 'Ogre Zombie', 'url': 'http://www.dnd5eapi.co/api/monsters/214'},
#   {'name': 'Oni', 'url': 'http://www.dnd5eapi.co/api/monsters/215'},
#   {'name': 'Orc', 'url': 'http://www.dnd5eapi.co/api/monsters/216'},
#   {'name': 'Otyugh', 'url': 'http://www.dnd5eapi.co/api/monsters/217'},
#   {'name': 'Owl', 'url': 'http://www.dnd5eapi.co/api/monsters/218'},
#   {'name': 'Owlbear', 'url': 'http://www.dnd5eapi.co/api/monsters/219'},
#   {'name': 'Panther', 'url': 'http://www.dnd5eapi.co/api/monsters/220'},
#   {'name': 'Pegasus', 'url': 'http://www.dnd5eapi.co/api/monsters/221'},
#   {'name': 'Phase Spider', 'url': 'http://www.dnd5eapi.co/api/monsters/222'},
#   {'name': 'Pit Fiend', 'url': 'http://www.dnd5eapi.co/api/monsters/223'},
#   {'name': 'Planetar', 'url': 'http://www.dnd5eapi.co/api/monsters/224'},
#   {'name': 'Plesiosaurus', 'url': 'http://www.dnd5eapi.co/api/monsters/225'},
#   {'name': 'Poisonous Snake',
#    'url': 'http://www.dnd5eapi.co/api/monsters/226'},
#   {'name': 'Polar Bear', 'url': 'http://www.dnd5eapi.co/api/monsters/227'},
#   {'name': 'Pony', 'url': 'http://www.dnd5eapi.co/api/monsters/228'},
#   {'name': 'Priest', 'url': 'http://www.dnd5eapi.co/api/monsters/229'},
#   {'name': 'Pseudodragon', 'url': 'http://www.dnd5eapi.co/api/monsters/230'},
#   {'name': 'Purple Worm', 'url': 'http://www.dnd5eapi.co/api/monsters/231'},
#   {'name': 'Quasit', 'url': 'http://www.dnd5eapi.co/api/monsters/232'},
#   {'name': 'Quipper', 'url': 'http://www.dnd5eapi.co/api/monsters/233'},
#   {'name': 'Rakshasa', 'url': 'http://www.dnd5eapi.co/api/monsters/234'},
#   {'name': 'Rat', 'url': 'http://www.dnd5eapi.co/api/monsters/235'},
#   {'name': 'Raven', 'url': 'http://www.dnd5eapi.co/api/monsters/236'},
#   {'name': 'Red Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/237'},
#   {'name': 'Reef Shark', 'url': 'http://www.dnd5eapi.co/api/monsters/238'},
#   {'name': 'Remorhaz', 'url': 'http://www.dnd5eapi.co/api/monsters/239'},
#   {'name': 'Rhinoceros', 'url': 'http://www.dnd5eapi.co/api/monsters/240'},
#   {'name': 'Riding Horse', 'url': 'http://www.dnd5eapi.co/api/monsters/241'},
#   {'name': 'Roc', 'url': 'http://www.dnd5eapi.co/api/monsters/242'},
#   {'name': 'Roper', 'url': 'http://www.dnd5eapi.co/api/monsters/243'},
#   {'name': 'Rug of Smothering',
#    'url': 'http://www.dnd5eapi.co/api/monsters/244'},
#   {'name': 'Rust Monster', 'url': 'http://www.dnd5eapi.co/api/monsters/245'},
#   {'name': 'Saber-Toothed Tiger',
#    'url': 'http://www.dnd5eapi.co/api/monsters/246'},
#   {'name': 'Sahuagin', 'url': 'http://www.dnd5eapi.co/api/monsters/247'},
#   {'name': 'Salamander', 'url': 'http://www.dnd5eapi.co/api/monsters/248'},
#   {'name': 'Satyr', 'url': 'http://www.dnd5eapi.co/api/monsters/249'},
#   {'name': 'Scorpion', 'url': 'http://www.dnd5eapi.co/api/monsters/250'},
#   {'name': 'Scout', 'url': 'http://www.dnd5eapi.co/api/monsters/251'},
#   {'name': 'Sea Hag', 'url': 'http://www.dnd5eapi.co/api/monsters/252'},
#   {'name': 'Sea Horse', 'url': 'http://www.dnd5eapi.co/api/monsters/253'},
#   {'name': 'Shadow', 'url': 'http://www.dnd5eapi.co/api/monsters/254'},
#   {'name': 'Shambling Mound',
#    'url': 'http://www.dnd5eapi.co/api/monsters/255'},
#   {'name': 'Shield Guardian',
#    'url': 'http://www.dnd5eapi.co/api/monsters/256'},
#   {'name': 'Shrieker', 'url': 'http://www.dnd5eapi.co/api/monsters/257'},
#   {'name': 'Silver Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/258'},
#   {'name': 'Skeleton', 'url': 'http://www.dnd5eapi.co/api/monsters/259'},
#   {'name': 'Solar', 'url': 'http://www.dnd5eapi.co/api/monsters/260'},
#   {'name': 'Specter', 'url': 'http://www.dnd5eapi.co/api/monsters/261'},
#   {'name': 'Spider', 'url': 'http://www.dnd5eapi.co/api/monsters/262'},
#   {'name': 'Spirit Naga', 'url': 'http://www.dnd5eapi.co/api/monsters/263'},
#   {'name': 'Sprite', 'url': 'http://www.dnd5eapi.co/api/monsters/264'},
#   {'name': 'Spy', 'url': 'http://www.dnd5eapi.co/api/monsters/265'},
#   {'name': 'Steam Mephit', 'url': 'http://www.dnd5eapi.co/api/monsters/266'},
#   {'name': 'Stirge', 'url': 'http://www.dnd5eapi.co/api/monsters/267'},
#   {'name': 'Stone Giant', 'url': 'http://www.dnd5eapi.co/api/monsters/268'},
#   {'name': 'Stone Golem', 'url': 'http://www.dnd5eapi.co/api/monsters/269'},
#   {'name': 'Storm Giant', 'url': 'http://www.dnd5eapi.co/api/monsters/270'},
#   {'name': 'Succubus/Incubus',
#    'url': 'http://www.dnd5eapi.co/api/monsters/271'},
#   {'name': 'Swarm of Bats', 'url': 'http://www.dnd5eapi.co/api/monsters/272'},
#   {'name': 'Swarm of Beetles',
#    'url': 'http://www.dnd5eapi.co/api/monsters/273'},
#   {'name': 'Swarm of Centipedes',
#    'url': 'http://www.dnd5eapi.co/api/monsters/274'},
#   {'name': 'Swarm of Insects',
#    'url': 'http://www.dnd5eapi.co/api/monsters/275'},
#   {'name': 'Swarm of Poisonous Snakes',
#    'url': 'http://www.dnd5eapi.co/api/monsters/276'},
#   {'name': 'Swarm of Quippers',
#    'url': 'http://www.dnd5eapi.co/api/monsters/277'},
#   {'name': 'Swarm of Rats', 'url': 'http://www.dnd5eapi.co/api/monsters/278'},
#   {'name': 'Swarm of Ravens',
#    'url': 'http://www.dnd5eapi.co/api/monsters/279'},
#   {'name': 'Swarm of Spiders',
#    'url': 'http://www.dnd5eapi.co/api/monsters/280'},
#   {'name': 'Swarm of Wasps', 'url': 'http://www.dnd5eapi.co/api/monsters/281'},
#   {'name': 'Tarrasque', 'url': 'http://www.dnd5eapi.co/api/monsters/282'},
#   {'name': 'Thug', 'url': 'http://www.dnd5eapi.co/api/monsters/283'},
#   {'name': 'Tiger', 'url': 'http://www.dnd5eapi.co/api/monsters/284'},
#   {'name': 'Treant', 'url': 'http://www.dnd5eapi.co/api/monsters/285'},
#   {'name': 'Tribal Warrior', 'url': 'http://www.dnd5eapi.co/api/monsters/286'},
#   {'name': 'Triceratops', 'url': 'http://www.dnd5eapi.co/api/monsters/287'},
#   {'name': 'Troll', 'url': 'http://www.dnd5eapi.co/api/monsters/288'},
#   {'name': 'Tyrannosaurus Rex',
#    'url': 'http://www.dnd5eapi.co/api/monsters/289'},
#   {'name': 'Unicorn', 'url': 'http://www.dnd5eapi.co/api/monsters/290'},
#   {'name': 'Vampire', 'url': 'http://www.dnd5eapi.co/api/monsters/291'},
#   {'name': 'Vampire Spawn', 'url': 'http://www.dnd5eapi.co/api/monsters/292'},
#   {'name': 'Veteran', 'url': 'http://www.dnd5eapi.co/api/monsters/293'},
#   {'name': 'Violet Fungus', 'url': 'http://www.dnd5eapi.co/api/monsters/294'},
#   {'name': 'Vrock', 'url': 'http://www.dnd5eapi.co/api/monsters/295'},
#   {'name': 'Vulture', 'url': 'http://www.dnd5eapi.co/api/monsters/296'},
#   {'name': 'Warhorse', 'url': 'http://www.dnd5eapi.co/api/monsters/297'},
#   {'name': 'Warhorse Skeleton',
#    'url': 'http://www.dnd5eapi.co/api/monsters/298'},
#   {'name': 'Water Elemental',
#    'url': 'http://www.dnd5eapi.co/api/monsters/299'},
#   {'name': 'Weasel', 'url': 'http://www.dnd5eapi.co/api/monsters/300'},
#   {'name': 'Werebear', 'url': 'http://www.dnd5eapi.co/api/monsters/301'},
#   {'name': 'Wereboar', 'url': 'http://www.dnd5eapi.co/api/monsters/302'},
#   {'name': 'Wererat', 'url': 'http://www.dnd5eapi.co/api/monsters/303'},
#   {'name': 'Weretiger', 'url': 'http://www.dnd5eapi.co/api/monsters/304'},
#   {'name': 'Werewolf', 'url': 'http://www.dnd5eapi.co/api/monsters/305'},
#   {'name': 'White Dragon Wyrmling',
#    'url': 'http://www.dnd5eapi.co/api/monsters/306'},
#   {'name': 'Wight', 'url': 'http://www.dnd5eapi.co/api/monsters/307'},
#   {'name': "Will-o'-Wisp", 'url': 'http://www.dnd5eapi.co/api/monsters/308'},
#   {'name': 'Winter Wolf', 'url': 'http://www.dnd5eapi.co/api/monsters/309'},
#   {'name': 'Wolf', 'url': 'http://www.dnd5eapi.co/api/monsters/310'},
#   {'name': 'Worg', 'url': 'http://www.dnd5eapi.co/api/monsters/311'},
#   {'name': 'Wraith', 'url': 'http://www.dnd5eapi.co/api/monsters/312'},
#   {'name': 'Wyvern', 'url': 'http://www.dnd5eapi.co/api/monsters/313'},
#   {'name': 'Xorn', 'url': 'http://www.dnd5eapi.co/api/monsters/314'},
#   {'name': 'Young Black Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/315'},
#   {'name': 'Young Blue Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/316'},
#   {'name': 'Young Brass Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/317'},
#   {'name': 'Young Bronze Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/318'},
#   {'name': 'Young Copper Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/319'},
#   {'name': 'Young Gold Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/320'},
#   {'name': 'Young Green Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/321'},
#   {'name': 'Young Red Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/322'},
#   {'name': 'Young Silver Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/323'},
#   {'name': 'Young White Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/324'},
#   {'name': 'Zombie', 'url': 'http://www.dnd5eapi.co/api/monsters/325'}]}

# %%
#step through to get monster details
monster_details = []
monurl_list = []

for monster in monster_names["results"]:
    mon_url = monster["url"]
    monurl_list.append(mon_url)
    mon_dets = requests.get(mon_url).json()
    monster_details.append(mon_dets)
pprint(monster_details)
# Out:
# [{'_id': '5bce91465b7768e7920181a5',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The aboleth makes three tentacle attacks.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 9,
#                'damage_bonus': 5,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +9 to hit, reach 10 ft., one '
#                        'target. Hit: 12 (2d6 + 5) bludgeoning damage. If the '
#                        'target is a creature, it must succeed on a DC 14 '
#                        'Constitution saving throw or become diseased. The '
#                        'disease has no effect for 1 minute and can be removed '
#                        'by any magic that cures disease. After 1 minute, the '
#                        "diseased creature's skin becomes translucent and "
#                        "slimy, the creature can't regain hit points unless it "
#                        'is underwater, and the disease can be removed only by '
#                        'heal or another disease-curing spell of 6th level or '
#                        'higher. When the creature is outside a body of water, '
#                        'it takes 6 (1d12) acid damage every 10 minutes unless '
#                        'moisture is applied to the skin before 10 minutes have '
#                        'passed.',
#                'name': 'Tentacle'},
#               {'attack_bonus': 9,
#                'damage_bonus': 5,
#                'damage_dice': '3d6',
#                'desc': 'Melee Weapon Attack: +9 to hit, reach 10 ft. one '
#                        'target. Hit: 15 (3d6 + 5) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': 'The aboleth targets one creature it can see within 30 '
#                        'ft. of it. The target must succeed on a DC 14 Wisdom '
#                        'saving throw or be magically charmed by the aboleth '
#                        'until the aboleth dies or until it is on a different '
#                        'plane of existence from the target. The charmed target '
#                        "is under the aboleth's control and can't take "
#                        'reactions, and the aboleth and the target can '
#                        'communicate telepathically with each other over any '
#                        'distance.\n'
#                        'Whenever the charmed target takes damage, the target '
#                        'can repeat the saving throw. On a success, the effect '
#                        'ends. No more than once every 24 hours, the target can '
#                        'also repeat the saving throw when it is at least 1 '
#                        'mile away from the aboleth.',
#                'name': 'Enslave (3/day)'}],
#   'alignment': 'lawful evil',
#   'armor_class': 17,
#   'challenge_rating': 10,
#   'condition_immunities': '',
#   'constitution': 15,
#   'constitution_save': 6,
#   'damage_immunities': '',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 9,
#   'history': 12,
#   'hit_dice': '18d10',
#   'hit_points': 135,
#   'index': 1,
#   'intelligence': 18,
#   'intelligence_save': 8,
#   'languages': 'Deep Speech, telepathy 120 ft.',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The aboleth makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The aboleth makes one tail attack.',
#                          'name': 'Tail Swipe'},
#                         {'attack_bonus': 0,
#                          'desc': 'One creature charmed by the aboleth takes 10 '
#                                  '(3d6) psychic damage, and the aboleth '
#                                  'regains hit points equal to the damage the '
#                                  'creature takes.',
#                          'name': 'Psychic Drain (Costs 2 Actions)'}],
#   'name': 'Aboleth',
#   'perception': 10,
#   'senses': 'darkvision 120 ft., passive Perception 20',
#   'size': 'Large',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The aboleth can breathe air and water.',
#                          'name': 'Amphibious'},
#                         {'attack_bonus': 0,
#                          'desc': 'While underwater, the aboleth is surrounded '
#                                  'by transformative mucus. A creature that '
#                                  'touches the aboleth or that hits it with a '
#                                  'melee attack while within 5 ft. of it must '
#                                  'make a DC 14 Constitution saving throw. On a '
#                                  'failure, the creature is diseased for 1d4 '
#                                  'hours. The diseased creature can breathe '
#                                  'only underwater.',
#                          'name': 'Mucous Cloud'},
#                         {'attack_bonus': 0,
#                          'desc': 'If a creature communicates telepathically '
#                                  'with the aboleth, the aboleth learns the '
#                                  "creature's greatest desires if the aboleth "
#                                  'can see the creature.',
#                          'name': 'Probing Telepathy'}],
#   'speed': '10 ft., swim 40 ft.',
#   'strength': 21,
#   'subtype': '',
#   'type': 'aberration',
#   'url': 'http://www.dnd5eapi.co/api/monsters/1',
#   'wisdom': 15,
#   'wisdom_save': 6},
#  {'_id': '5bce91465b7768e7920181a3',
#   'actions': [{'attack_bonus': 2,
#                'damage_dice': '1d4',
#                'desc': 'Melee Weapon Attack: +2 to hit, reach 5 ft., one '
#                        'target. Hit: 2 (1d4) bludgeoning damage.',
#                'name': 'Club'}],
#   'alignment': 'any alignment',
#   'armor_class': 10,
#   'challenge_rating': 0.25,
#   'charisma': 11,
#   'condition_immunities': '',
#   'constitution': 10,
#   'damage_immunities': '',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'hit_dice': '2d8',
#   'hit_points': 9,
#   'index': 2,
#   'intelligence': 10,
#   'languages': 'any one language (usually Common)',
#   'medicine': 4,
#   'name': 'Acolyte',
#   'religion': 2,
#   'senses': 'passive Perception 12',
#   'size': 'Medium',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The acolyte is a 1st-level spellcaster. Its '
#                                  'spellcasting ability is Wisdom (spell save '
#                                  'DC 12, +4 to hit with spell attacks). The '
#                                  'acolyte has following cleric spells '
#                                  'prepared:\n'
#                                  '\n'
#                                  '• Cantrips (at will): light, sacred flame, '
#                                  'thaumaturgy\n'
#                                  '• 1st level (3 slots): bless, cure wounds, '
#                                  'sanctuary',
#                          'name': 'Spellcasting'}],
#   'speed': '30 ft.',
#   'strength': 10,
#   'subtype': 'any race',
#   'type': 'humanoid',
#   'url': 'http://www.dnd5eapi.co/api/monsters/2',
#   'wisdom': 14},
#  {'_id': '5bce91465b7768e7920181a4',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d10 + 1d8',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 10 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage plus 4 '
#                        '(1d8) acid damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 15 ft., one '
#                        'target. Hit: 15 (2d8 + 6) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 feet of the dragon and aware of it must succeed on '
#                        'a DC 16 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d8',
#                'desc': 'The dragon exhales acid in a 60-foot line that is 5 '
#                        'feet wide. Each creature in that line must make a DC '
#                        '18 Dexterity saving throw, taking 54 (12d8) acid '
#                        'damage on a failed save, or half as much damage on a '
#                        'successful one.',
#                'name': 'Acid Breath (Recharge 5-6)'}],
#   'alignment': 'chaotic evil',
#   'armor_class': 19,
#   'challenge_rating': 14,
#   'charisma': 17,
#   'charisma_save': 8,
#   'condition_immunities': '',
#   'constitution': 21,
#   'constitution_save': 10,
#   'damage_immunities': 'acid',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 14,
#   'dexterity_save': 7,
#   'hit_dice': '17d12',
#   'hit_points': 195,
#   'index': 3,
#   'intelligence': 14,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dragon makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon beats its wings. Each creature '
#                                  'within 10 ft. of the dragon must succeed on '
#                                  'a DC 19 Dexterity saving throw or take 13 '
#                                  '(2d6 + 6) bludgeoning damage and be knocked '
#                                  'prone. The dragon can then fly up to half '
#                                  'its flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Black Dragon',
#   'perception': 11,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 21',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can breathe air and water.',
#                          'name': 'Amphibious'},
#                         {'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 7,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/3',
#   'wisdom': 13,
#   'wisdom_save': 6},
#  {'_id': '5bce91465b7768e7920181b3',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dracolich can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d10 + 1d10',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 10 ft., one '
#                        'target. Hit: 18 (2d10 + 7) piercing damage plus 5 '
#                        '(1d10) lightning damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 5 ft., one '
#                        'target. Hit: 14 (2d6 + 7) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 15 ft., one '
#                        'target. Hit: 16 (2d8 + 7) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dracolich's choice that is within "
#                        '120 feet of the dracolich and aware of it must succeed '
#                        'on a DC 18 Wisdom saving throw or become frightened '
#                        'for 1 minute. A creature can repeat the saving throw '
#                        'at the end of each of its turns, ending the effect on '
#                        "itself on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dracolich's Frightful Presence for the "
#                        'next 24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d10',
#                'desc': 'The dracolich exhales lightning in a 90-foot line that '
#                        'is 5 feet wide. Each creature in that line must make a '
#                        'DC 20 Dexterity saving throw, taking 66 (12d10) '
#                        'lightning damage on a failed save, or half as much '
#                        'damage on a successful one.',
#                'name': 'Lightning Breath (Recharge 5-6)'}],
#   'alignment': 'lawful evil',
#   'armor_class': 19,
#   'challenge_rating': 17,
#   'charisma': 19,
#   'condition_immunities': 'charmed, exhaustion, frightened, paralyzed, '
#                           'poisoned',
#   'constitution': 23,
#   'damage_immunities': 'lightning, poison',
#   'damage_resistances': 'necrotic',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'hit_dice': '18d12',
#   'hit_points': 225,
#   'index': 4,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dracolich makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dracolich makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dracolich beats its tattered wings. Each '
#                                  'creature within 10 ft. of the dracolich must '
#                                  'succeed on a DC 21 Dexterity saving throw or '
#                                  'take 14 (2d6 + 7) bludgeoning damage and be '
#                                  'knocked prone. After beating its wings this '
#                                  'way, the dracolich can fly up to half its '
#                                  'flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Blue Dracolich',
#   'perception': 12,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 22',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'If the dracolich fails a saving throw, it '
#                                  'can choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dracolich has advantage on saving throws '
#                                  'against spells and other magical effects.',
#                          'name': 'Magic Resistance'}],
#   'speed': '40 ft., burrow 30 ft., fly 80 ft.',
#   'strength': 25,
#   'subtype': '',
#   'type': 'undead',
#   'url': 'http://www.dnd5eapi.co/api/monsters/4',
#   'wisdom': 15},
#  {'_id': '5bce91465b7768e7920181a6',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d10 + 1d10',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 10 ft., one '
#                        'target. Hit: 18 (2d10 + 7) piercing damage plus 5 '
#                        '(1d10) lightning damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 5 ft., one '
#                        'target. Hit: 14 (2d6 + 7) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 15 ft., one '
#                        'target. Hit: 16 (2d8 + 7) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 ft. of the dragon and aware of it must succeed on '
#                        'a DC 17 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d10',
#                'desc': 'The dragon exhales lightning in a 90-foot line that is '
#                        '5 ft. wide. Each creature in that line must make a DC '
#                        '19 Dexterity saving throw, taking 66 (12d10) lightning '
#                        'damage on a failed save, or half as much damage on a '
#                        'successful one.',
#                'name': 'Lightning Breath (Recharge 5-6)'}],
#   'alignment': 'lawful evil',
#   'armor_class': 19,
#   'challenge_rating': 16,
#   'charisma': 19,
#   'charisma_save': 9,
#   'condition_immunities': '',
#   'constitution': 23,
#   'constitution_save': 11,
#   'damage_immunities': 'lightning',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'dexterity_save': 5,
#   'hit_dice': '18d12',
#   'hit_points': 225,
#   'index': 5,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dragon makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon beats its wings. Each creature '
#                                  'within 10 ft. of the dragon must succeed on '
#                                  'a DC 20 Dexterity saving throw or take 14 '
#                                  '(2d6 + 7) bludgeoning damage and be knocked '
#                                  'prone. The dragon can then fly up to half '
#                                  'its flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Blue Dragon',
#   'perception': 12,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 22',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., burrow 30 ft., fly 80 ft.',
#   'stealth': 5,
#   'strength': 25,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/5',
#   'wisdom': 15,
#   'wisdom_save': 7},
#  {'_id': '5bce91465b7768e7920181a7',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d10',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach,.0 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 15 ft., one '
#                        'target. Hit: 15 (2d8 + 6) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 feet of the dragon and aware of it must succeed on '
#                        'a DC 16 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '13d6',
#                'desc': 'The dragon uses one of the following breath weapons.\n'
#                        'Fire Breath. The dragon exhales fire in an 60-foot '
#                        'line that is 5 feet wide. Each creature in that line '
#                        'must make a DC 18 Dexterity saving throw, taking 45 '
#                        '(13d6) fire damage on a failed save, or half as much '
#                        'damage on a successful one.\n'
#                        'Sleep Breath. The dragon exhales sleep gas in a '
#                        '60-foot cone. Each creature in that area must succeed '
#                        'on a DC 18 Constitution saving throw or fall '
#                        'unconscious for 10 minutes. This effect ends for a '
#                        'creature if the creature takes damage or someone uses '
#                        'an action to wake it.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'chaotic good',
#   'armor_class': 18,
#   'challenge_rating': 13,
#   'charisma': 17,
#   'charisma_save': 8,
#   'condition_immunities': '',
#   'constitution': 21,
#   'constitution_save': 10,
#   'damage_immunities': 'fire',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'dexterity_save': 5,
#   'history': 7,
#   'hit_dice': '15d12',
#   'hit_points': 172,
#   'index': 6,
#   'intelligence': 14,
#   'languages': 'Common, Draconic',
#   'name': 'Adult Brass Dragon',
#   'perception': 11,
#   'persuasion': 8,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 21',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., burrow 40 ft., fly 80 ft.',
#   'stealth': 5,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/6',
#   'wisdom': 13,
#   'wisdom_save': 6},
#  {'_id': '5bce91465b7768e7920181a9',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d10',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 10 ft., one '
#                        'target. Hit: 18 (2d10 + 7) piercing damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 5 ft., one '
#                        'target. Hit: 14 (2d6 + 7) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 12,
#                'damage_bonus': 7,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +12 to hit, reach 15 ft., one '
#                        'target. Hit: 16 (2d8 + 7) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 feet of the dragon and aware of it must succeed on '
#                        'a DC 17 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d10',
#                'desc': 'The dragon uses one of the following breath weapons.\n'
#                        'Lightning Breath. The dragon exhales lightning in a '
#                        '90-foot line that is 5 feet wide. Each creature in '
#                        'that line must make a DC 19 Dexterity saving throw, '
#                        'taking 66 (12d10) lightning damage on a failed save, '
#                        'or half as much damage on a successful one.\n'
#                        'Repulsion Breath. The dragon exhales repulsion energy '
#                        'in a 30-foot cone. Each creature in that area must '
#                        'succeed on a DC 19 Strength saving throw. On a failed '
#                        'save, the creature is pushed 60 feet away from the '
#                        'dragon.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'lawful good',
#   'armor_class': 19,
#   'challenge_rating': 15,
#   'charisma': 19,
#   'charisma_save': 9,
#   'condition_immunities': '',
#   'constitution': 23,
#   'constitution_save': 11,
#   'damage_immunities': 'lightning',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'dexterity_save': 5,
#   'hit_dice': '17d12',
#   'hit_points': 212,
#   'index': 7,
#   'insight': 7,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dragon makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon beats its wings. Each creature '
#                                  'within 10 ft. of the dragon must succeed on '
#                                  'a DC 20 Dexterity saving throw or take 14 '
#                                  '(2d6 + 7) bludgeoning damage and be knocked '
#                                  'prone. The dragon can then fly up to half '
#                                  'its flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Bronze Dragon',
#   'perception': 12,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 22',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can breathe air and water.',
#                          'name': 'Amphibious'},
#                         {'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 5,
#   'strength': 25,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/7',
#   'wisdom': 15,
#   'wisdom_save': 7},
#  {'_id': '5bce91465b7768e7920181a8',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d10',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 10 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 15 ft., one '
#                        'target. Hit: 15 (2d8 + 6) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 feet of the dragon and aware of it must succeed on '
#                        'a DC 16 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d8',
#                'desc': 'The dragon uses one of the following breath weapons.\n'
#                        'Acid Breath. The dragon exhales acid in an 60-foot '
#                        'line that is 5 feet wide. Each creature in that line '
#                        'must make a DC 18 Dexterity saving throw, taking 54 '
#                        '(12d8) acid damage on a failed save, or half as much '
#                        'damage on a successful one.\n'
#                        'Slowing Breath. The dragon exhales gas in a 60-foot '
#                        'cone. Each creature in that area must succeed on a DC '
#                        '18 Constitution saving throw. On a failed save, the '
#                        "creature can't use reactions, its speed is halved, and "
#                        "it can't make more than one attack on its turn. In "
#                        'addition, the creature can use either an action or a '
#                        'bonus action on its turn, but not both. These effects '
#                        'last for 1 minute. The creature can repeat the saving '
#                        'throw at the end of each of its turns, ending the '
#                        'effect on itself with a successful save.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'chaotic good',
#   'armor_class': 18,
#   'challenge_rating': 14,
#   'charisma': 17,
#   'charisma_save': 8,
#   'condition_immunities': '',
#   'constitution': 21,
#   'constitution_save': 10,
#   'damage_immunities': 'acid',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'deception': 8,
#   'dexterity': 12,
#   'dexterity_save': 6,
#   'hit_dice': '16d12',
#   'hit_points': 184,
#   'index': 8,
#   'intelligence': 18,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dragon makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon beats its wings. Each creature '
#                                  'within 10 ft. of the dragon must succeed on '
#                                  'a DC 19 Dexterity saving throw or take 13 '
#                                  '(2d6 + 6) bludgeoning damage and be knocked '
#                                  'prone. The dragon can then fly up to half '
#                                  'its flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Copper Dragon',
#   'perception': 12,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 22',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., climb 40 ft., fly 80 ft.',
#   'stealth': 6,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/8',
#   'wisdom': 15,
#   'wisdom_save': 7},
#  {'_id': '5bce91465b7768e7920181aa',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 14,
#                'damage_bonus': 8,
#                'damage_dice': '2d10',
#                'desc': 'Melee Weapon Attack: +14 to hit, reach 10 ft., one '
#                        'target. Hit: 19 (2d10 + 8) piercing damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 14,
#                'damage_bonus': 8,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +14 to hit, reach 5 ft., one '
#                        'target. Hit: 15 (2d6 + 8) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 14,
#                'damage_bonus': 8,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +14 to hit, reach 15 ft., one '
#                        'target. Hit: 17 (2d8 + 8) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 feet of the dragon and aware of it must succeed on '
#                        'a DC 21 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d10',
#                'desc': 'The dragon uses one of the following breath weapons.\n'
#                        'Fire Breath. The dragon exhales fire in a 60-foot '
#                        'cone. Each creature in that area must make a DC 21 '
#                        'Dexterity saving throw, taking 66 (12d10) fire damage '
#                        'on a failed save, or half as much damage on a '
#                        'successful one.\n'
#                        'Weakening Breath. The dragon exhales gas in a 60-foot '
#                        'cone. Each creature in that area must succeed on a DC '
#                        '21 Strength saving throw or have disadvantage on '
#                        'Strength-based attack rolls, Strength checks, and '
#                        'Strength saving throws for 1 minute. A creature can '
#                        'repeat the saving throw at the end of each of its '
#                        'turns, ending the effect on itself on a success.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'lawful good',
#   'armor_class': 19,
#   'challenge_rating': 17,
#   'charisma': 24,
#   'charisma_save': 13,
#   'condition_immunities': '',
#   'constitution': 25,
#   'constitution_save': 13,
#   'damage_immunities': 'fire',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 14,
#   'dexterity_save': 8,
#   'hit_dice': '19d12',
#   'hit_points': 256,
#   'index': 9,
#   'insight': 8,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dragon makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon beats its wings. Each creature '
#                                  'within 10 ft. of the dragon must succeed on '
#                                  'a DC 22 Dexterity saving throw or take 15 '
#                                  '(2d6 + 8) bludgeoning damage and be knocked '
#                                  'prone. The dragon can then fly up to half '
#                                  'its flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Gold Dragon',
#   'perception': 14,
#   'persuasion': 13,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 24',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can breathe air and water.',
#                          'name': 'Amphibious'},
#                         {'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 8,
#   'strength': 27,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/9',
#   'wisdom': 15,
#   'wisdom_save': 8},
#  {'_id': '5bce91465b7768e7920181ab',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d10 + 2d6',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 10 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage plus 7 '
#                        '(2d6) poison damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 11,
#                'damage_bonus': 6,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +11 to hit, reach 15 ft., one '
#                        'target. Hit: 15 (2d8 + 6) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 feet of the dragon and aware of it must succeed on '
#                        'a DC 16 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours .',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '16d6',
#                'desc': 'The dragon exhales poisonous gas in a 60-foot cone. '
#                        'Each creature in that area must make a DC 18 '
#                        'Constitution saving throw, taking 56 (16d6) poison '
#                        'damage on a failed save, or half as much damage on a '
#                        'successful one.',
#                'name': 'Poison Breath (Recharge 5-6)'}],
#   'alignment': 'lawful evil',
#   'armor_class': 19,
#   'challenge_rating': 15,
#   'charisma': 17,
#   'charisma_save': 8,
#   'condition_immunities': 'poisoned',
#   'constitution': 21,
#   'constitution_save': 10,
#   'damage_immunities': 'poison',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'deception': 8,
#   'dexterity': 12,
#   'dexterity_save': 6,
#   'hit_dice': '18d12',
#   'hit_points': 207,
#   'index': 10,
#   'insight': 7,
#   'intelligence': 18,
#   'languages': 'Common, Draconic',
#   'legendary_actions': [{'attack_bonus': 0,
#                          'desc': 'The dragon makes a Wisdom (Perception) '
#                                  'check.',
#                          'name': 'Detect'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon makes a tail attack.',
#                          'name': 'Tail Attack'},
#                         {'attack_bonus': 0,
#                          'desc': 'The dragon beats its wings. Each creature '
#                                  'within 10 ft. of the dragon must succeed on '
#                                  'a DC 19 Dexterity saving throw or take 13 '
#                                  '(2d6 + 6) bludgeoning damage and be knocked '
#                                  'prone. The dragon can then fly up to half '
#                                  'its flying speed.',
#                          'name': 'Wing Attack (Costs 2 Actions)'}],
#   'name': 'Adult Green Dragon',
#   'perception': 12,
#   'persuasion': 8,
#   'senses': 'blindsight 60 ft., darkvision 120 ft., passive Perception 22',
#   'size': 'Huge',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can breathe air and water.',
#                          'name': 'Amphibious'},
#                         {'attack_bonus': 0,
#                          'desc': 'If the dragon fails a saving throw, it can '
#                                  'choose to succeed instead.',
#                          'name': 'Legendary Resistance (3/Day)'}],
#   'speed': '40 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 6,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/10',
#   'wisdom': 15,
#   'wisdom_save': 7},
#  {'_id': '5bce91465b7768e7920181ac',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon can use its Frightful Presence. It then '
#                        'makes three attacks: one with its bite and two with '
#                        'its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 14,
#                'damage_bonus': 8,
#                'damage_dice': '2d10 + 2d6',
#                'desc': 'Melee Weapon Attack: +14 to hit, reach 10 ft., one '
#                        'target. Hit: 19 (2d10 + 8) piercing damage plus 7 '
#                        '(2d6) fire damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 14,
#                'damage_bonus': 8,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +14 to hit, reach 5 ft., one '
#                        'target. Hit: 15 (2d6 + 8) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 14,
#                'damage_bonus': 8,
#                'damage_dice': '2d8',
#                'desc': 'Melee Weapon Attack: +14 to hit, reach 15 ft., one '
#                        'target. Hit: 17 (2d8 + 8) bludgeoning damage.',
#                'name': 'Tail'},
#               {'attack_bonus': 0,
#                'desc': "Each creature of the dragon's choice that is within "
#                        '120 ft. of the dragon and aware of it must succeed on '
#                        'a DC 19 Wisdom saving throw or become frightened for 1 '
#                        'minute. A creature can repeat the saving throw at the '
#                        'end of each of its turns, ending the effect on itself '
#                        "on a success. If a creature's saving throw is "
#                        'successful or the effect ends for it, the creature is '
#                        "immune to the dragon's Frightful Presence for the next "
#                        '24 hours.',
#                'name': 'Frightful Presence'},
#               {'attack_bonus': 0,
#                'damage_dice': '18d6',
#                'desc': 'The dragon exhales fire in a 60-foot cone. Each '
#                        'creature in that area must make a DC 21 Dexterity '
#                        'saving throw, taking 63 (18d6) fire damage on a failed '
#                        'save, or half as much damage on a successful one.',
#                'name': 'Fire Breath (Recharge 5-6)'},
#               {'attack_bonus': 0,
#                'damage_dice': '6d6',
#                'desc': 'On initiative count 20 (losing initiative ties), the '
#                        'dragon takes a lair action to cause one of the '
#                        "following effects: the dragon can't use the same "
#                        'effect two rounds in a row:\n'
#                        '• Magma erupts from a point on the ground the dragon '
# ...
#                        'must make a DC 14 Dexterity saving throw, taking 40 '
#                        '(9d8) acid damage on a failed save, or half as much '
#                        'damage on a successful one.\n'
#                        'Slowing Breath. The dragon exhales gas in a 30-foot '
#                        'cone. Each creature in that area must succeed on a DC '
#                        '14 Constitution saving throw. On a failed save, the '
#                        "creature can't use reactions, its speed is halved, and "
#                        "it can't make more than one attack on its turn. In "
#                        'addition, the creature can use either an action or a '
#                        'bonus action on its turn, but not both. These effects '
#                        'last for 1 minute. The creature can repeat the saving '
#                        'throw at the end of each of its turns, ending the '
#                        'effect on itself with a successful save.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'chaotic good',
#   'armor_class': 17,
#   'challenge_rating': 7,
#   'charisma': 15,
#   'charisma_save': 5,
#   'condition_immunities': '',
#   'constitution': 17,
#   'constitution_save': 6,
#   'damage_immunities': 'acid',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'deception': 5,
#   'dexterity': 12,
#   'dexterity_save': 4,
#   'hit_dice': '14d10',
#   'hit_points': 119,
#   'index': 319,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'name': 'Young Copper Dragon',
#   'perception': 7,
#   'senses': 'blindsight 30 ft., darkvision 120 ft., passive Perception 17',
#   'size': 'Large',
#   'speed': '40 ft., climb 40 ft., fly 80 ft.',
#   'stealth': 4,
#   'strength': 19,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/319',
#   'wisdom': 13,
#   'wisdom_save': 4},
#  {'_id': '5bce91465b7768e7920182e2',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon makes three attacks: one with its bite and '
#                        'two with its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 10,
#                'damage_bonus': 6,
#                'damage_dice': '2d10',
#                'desc': 'Melee Weapon Attack: +10 to hit, reach 10 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 10,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +10 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 0,
#                'damage_dice': '10d10',
#                'desc': 'The dragon uses one of the following breath weapons.\n'
#                        'Fire Breath. The dragon exhales fire in a 30-foot '
#                        'cone. Each creature in that area must make a DC 17 '
#                        'Dexterity saving throw, taking 55 (10d10) fire damage '
#                        'on a failed save, or half as much damage on a '
#                        'successful one.\n'
#                        'Weakening Breath. The dragon exhales gas in a 30-foot '
#                        'cone. Each creature in that area must succeed on a DC '
#                        '17 Strength saving throw or have disadvantage on '
#                        'Strength-based attack rolls, Strength checks, and '
#                        'Strength saving throws for 1 minute. A creature can '
#                        'repeat the saving throw at the end of each of its '
#                        'turns, ending the effect on itself on a success.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'lawful good',
#   'armor_class': 18,
#   'challenge_rating': 10,
#   'charisma': 20,
#   'charisma_save': 9,
#   'condition_immunities': '',
#   'constitution': 21,
#   'constitution_save': 9,
#   'damage_immunities': 'fire',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 14,
#   'dexterity_save': 6,
#   'hit_dice': '17d10',
#   'hit_points': 178,
#   'index': 320,
#   'insight': 5,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'name': 'Young Gold Dragon',
#   'perception': 9,
#   'persuasion': 9,
#   'senses': 'blindsight 30 ft., darkvision 120 ft., passive Perception 19',
#   'size': 'Large',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can breathe air and water.',
#                          'name': 'Amphibious'}],
#   'speed': '40 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 6,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/320',
#   'wisdom': 13,
#   'wisdom_save': 5},
#  {'_id': '5bce91465b7768e7920182e3',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon makes three attacks: one with its bite and '
#                        'two with its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 7,
#                'damage_bonus': 4,
#                'damage_dice': '2d10 + 2d6',
#                'desc': 'Melee Weapon Attack: +7 to hit, reach 10 ft., one '
#                        'target. Hit: 15 (2d10 + 4) piercing damage plus 7 '
#                        '(2d6) poison damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 7,
#                'damage_bonus': 4,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +7 to hit, reach 5 ft., one '
#                        'target. Hit: 11 (2d6 + 4) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d6',
#                'desc': 'The dragon exhales poisonous gas in a 30-foot cone. '
#                        'Each creature in that area must make a DC 14 '
#                        'Constitution saving throw, taking 42 (12d6) poison '
#                        'damage on a failed save, or half as much damage on a '
#                        'successful one.',
#                'name': 'Poison Breath (Recharge 5-6)'}],
#   'alignment': 'lawful evil',
#   'armor_class': 18,
#   'challenge_rating': 8,
#   'charisma': 15,
#   'charisma_save': 5,
#   'condition_immunities': 'poisoned',
#   'constitution': 17,
#   'constitution_save': 6,
#   'damage_immunities': 'poison',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'deception': 5,
#   'dexterity': 12,
#   'dexterity_save': 4,
#   'hit_dice': '16d10',
#   'hit_points': 136,
#   'index': 321,
#   'intelligence': 16,
#   'languages': 'Common, Draconic',
#   'name': 'Young Green Dragon',
#   'perception': 7,
#   'senses': 'blindsight 30 ft., darkvision 120 ft., passive Perception 17',
#   'size': 'Large',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can breathe air and water.',
#                          'name': 'Amphibious'}],
#   'speed': '40 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 4,
#   'strength': 19,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/321',
#   'wisdom': 13,
#   'wisdom_save': 4},
#  {'_id': '5bce91465b7768e7920182e5',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon makes three attacks: one with its bite and '
#                        'two with its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 10,
#                'damage_bonus': 6,
#                'damage_dice': '2d10 + 1d6',
#                'desc': 'Melee Weapon Attack: +10 to hit, reach 10 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage plus 3 '
#                        '(1d6) fire damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 10,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +10 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 0,
#                'damage_dice': '16d6',
#                'desc': 'The dragon exhales fire in a 30-foot cone. Each '
#                        'creature in that area must make a DC 17 Dexterity '
#                        'saving throw, taking 56 (16d6) fire damage on a failed '
#                        'save, or half as much damage on a successful one.',
#                'name': 'Fire Breath (Recharge 5-6)'}],
#   'alignment': 'chaotic evil',
#   'armor_class': 18,
#   'challenge_rating': 10,
#   'charisma': 19,
#   'charisma_save': 8,
#   'condition_immunities': '',
#   'constitution': 21,
#   'constitution_save': 9,
#   'damage_immunities': 'fire',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'dexterity_save': 4,
#   'hit_dice': '17d10',
#   'hit_points': 178,
#   'index': 322,
#   'intelligence': 14,
#   'languages': 'Common, Draconic',
#   'name': 'Young Red Dragon',
#   'perception': 8,
#   'senses': 'blindsight 30 ft., darkvision 120 ft., passive Perception 18',
#   'size': 'Large',
#   'speed': '40 ft., climb 40 ft., fly 80 ft.',
#   'stealth': 4,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/322',
#   'wisdom': 11,
#   'wisdom_save': 4},
#  {'_id': '5bce91465b7768e7920182e4',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon makes three attacks: one with its bite and '
#                        'two with its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 10,
#                'damage_bonus': 6,
#                'damage_dice': '2d10',
#                'desc': 'Melee Weapon Attack: +10 to hit, reach 10 ft., one '
#                        'target. Hit: 17 (2d10 + 6) piercing damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 10,
#                'damage_bonus': 6,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +10 to hit, reach 5 ft., one '
#                        'target. Hit: 13 (2d6 + 6) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 0,
#                'damage_dice': '12d8',
#                'desc': 'The dragon uses one of the following breath weapons.\n'
#                        'Cold Breath. The dragon exhales an icy blast in a '
#                        '30-foot cone. Each creature in that area must make a '
#                        'DC 17 Constitution saving throw, taking 54 (12d8) cold '
#                        'damage on a failed save, or half as much damage on a '
#                        'successful one.\n'
#                        'Paralyzing Breath. The dragon exhales paralyzing gas '
#                        'in a 30-foot cone. Each creature in that area must '
#                        'succeed on a DC 17 Constitution saving throw or be '
#                        'paralyzed for 1 minute. A creature can repeat the '
#                        'saving throw at the end of each of its turns, ending '
#                        'the effect on itself on a success.',
#                'name': 'Breath Weapons (Recharge 5-6)'}],
#   'alignment': 'lawful good',
#   'arcana': 6,
#   'armor_class': 18,
#   'challenge_rating': 9,
#   'charisma': 19,
#   'charisma_save': 8,
#   'condition_immunities': '',
#   'constitution': 21,
#   'constitution_save': 9,
#   'damage_immunities': 'cold',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'dexterity_save': 4,
#   'history': 6,
#   'hit_dice': '16d10',
#   'hit_points': 168,
#   'index': 323,
#   'intelligence': 14,
#   'languages': 'Common, Draconic',
#   'name': 'Young Silver Dragon',
#   'perception': 8,
#   'senses': 'blindsight 30 ft., darkvision 120 ft., passive Perception 18',
#   'size': 'Large',
#   'speed': '40 ft., fly 80 ft.',
#   'stealth': 4,
#   'strength': 23,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/323',
#   'wisdom': 11,
#   'wisdom_save': 4},
#  {'_id': '5bce91465b7768e7920182e7',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The dragon makes three attacks: one with its bite and '
#                        'two with its claws.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 7,
#                'damage_bonus': 4,
#                'damage_dice': '2d10 + 1d8',
#                'desc': 'Melee Weapon Attack: +7 to hit, reach 10 ft., one '
#                        'target. Hit: 15 (2d10 + 4) piercing damage plus 4 '
#                        '(1d8) cold damage.',
#                'name': 'Bite'},
#               {'attack_bonus': 7,
#                'damage_bonus': 4,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +7 to hit, reach 5 ft., one '
#                        'target. Hit: 11 (2d6 + 4) slashing damage.',
#                'name': 'Claw'},
#               {'attack_bonus': 0,
#                'damage_dice': '10d8',
#                'desc': 'The dragon exhales an icy blast in a 30-foot cone. '
#                        'Each creature in that area must make a DC 15 '
#                        'Constitution saving throw, taking 45 (10d8) cold '
#                        'damage on a failed save, or half as much damage on a '
#                        'successful one.',
#                'name': 'Cold Breath (Recharge 5-6)'}],
#   'alignment': 'chaotic evil',
#   'armor_class': 17,
#   'challenge_rating': 6,
#   'charisma': 12,
#   'charisma_save': 4,
#   'condition_immunities': '',
#   'constitution': 18,
#   'constitution_save': 7,
#   'damage_immunities': 'cold',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 10,
#   'dexterity_save': 3,
#   'hit_dice': '14d10',
#   'hit_points': 133,
#   'index': 324,
#   'intelligence': 6,
#   'languages': 'Common, Draconic',
#   'name': 'Young White Dragon',
#   'perception': 6,
#   'senses': 'blindsight 30 ft., darkvision 120 ft., passive Perception 16',
#   'size': 'Large',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'The dragon can move across and climb icy '
#                                  'surfaces without needing to make an ability '
#                                  'check. Additionally, difficult terrain '
#                                  "composed of ice or snow doesn't cost it "
#                                  'extra moment.',
#                          'name': 'Ice Walk'}],
#   'speed': '40 ft., burrow 20 ft., fly 80 ft., swim 40 ft.',
#   'stealth': 3,
#   'strength': 18,
#   'subtype': '',
#   'type': 'dragon',
#   'url': 'http://www.dnd5eapi.co/api/monsters/324',
#   'wisdom': 11,
#   'wisdom_save': 3},
#  {'_id': '5bce91465b7768e7920182e6',
#   'actions': [{'attack_bonus': 3,
#                'damage_bonus': 1,
#                'damage_dice': '1d6',
#                'desc': 'Melee Weapon Attack: +3 to hit, reach 5 ft., one '
#                        'target. Hit: 4 (1d6 + 1) bludgeoning damage.',
#                'name': 'Slam'}],
#   'alignment': 'neutral evil',
#   'armor_class': 8,
#   'challenge_rating': 0.25,
#   'charisma': 5,
#   'condition_immunities': 'poisoned',
#   'constitution': 16,
#   'damage_immunities': '',
#   'damage_resistances': '',
#   'damage_vulnerabilities': '',
#   'dexterity': 6,
#   'hit_dice': '3d8',
#   'hit_points': 22,
#   'index': 325,
#   'intelligence': 3,
#   'languages': "understands all languages it spoke in life but can't speak",
#   'name': 'Zombie',
#   'senses': 'darkvision 60 ft., passive Perception 8',
#   'size': 'Medium',
#   'special_abilities': [{'attack_bonus': 0,
#                          'desc': 'If damage reduces the zombie to 0 hit '
#                                  'points, it must make a Constitution saving '
#                                  'throw with a DC of 5+the damage taken, '
#                                  'unless the damage is radiant or from a '
#                                  'critical hit. On a success, the zombie drops '
#                                  'to 1 hit point instead.',
#                          'name': 'Undead Fortitude'}],
#   'speed': '20 ft.',
#   'strength': 13,
#   'subtype': '',
#   'type': 'undead',
#   'url': 'http://www.dnd5eapi.co/api/monsters/325',
#   'wisdom': 6,
#   'wisdom_save': 0}]

# %%
#Need to convert monster_details into a dataframe

# %%
#pprint(monster_details[0]["name"])

Monsternames=[]
Monstersize = []
MonsterHP = []
MonsterIntelligence = []
MonsterDexterity = []
MonsterChallengeR = []
MonsterWisdom = []
MonsterStrength = []
MonsterType = []


for x in monster_details:
    monName = x["name"]
    Monsternames.append(monName)
    monSize = x["size"]
    Monstersize.append(monSize)
    monHP = x["hit_points"]
    MonsterHP.append(monHP)
    MonInt = x["intelligence"]
    MonsterIntelligence.append(MonInt)
    MonDex = x["dexterity"]
    MonsterDexterity.append(MonDex)
    MonChal = x["challenge_rating"]
    MonsterChallengeR.append(MonChal)
    MonStr = x["strength"]
    MonsterStrength.append(MonStr)
    MonWis = x["wisdom"]
    MonsterWisdom.append(MonWis)
    MonType = x["type"]
    MonsterType.append(MonType)
    
    
      
    
Monsternames

monster = pd.DataFrame()
monster["name"] = Monsternames
monster["type"] = MonsterType
monster["size"] = Monstersize
monster["HP"] = MonsterHP
monster["Challenge Rating"] = MonsterChallengeR
monster["intelligence"] = MonsterIntelligence
monster["strength"] = MonsterStrength
monster["wisdom"] = MonsterWisdom
monster["dexterity"] = MonsterDexterity


monster.head()
monster["type"].unique()
# Out:
# array(['aberration', 'humanoid', 'dragon', 'undead', 'elemental',
#        'monstrosity', 'construct', 'beast', 'plant', 'fiend', 'ooze',
#        'fey', 'giant', 'celestial', 'swarm of Tiny beasts'], dtype=object)

# %%
#group by avg stats
avg_stats_hp = monster.groupby("type")["HP"].mean()
avg_stats_hp
# Out:
# type
# aberration               97.400000
# beast                    25.545455
# celestial               133.666667
# construct                93.777778
# dragon                  202.139535
# elemental                77.562500
# fey                      35.166667
# fiend                   115.260870
# giant                   129.900000
# humanoid                 37.075000
# monstrosity             111.425000
# ooze                     59.000000
# plant                    62.333333
# swarm of Tiny beasts     24.400000
# undead                   64.473684
# Name: HP, dtype: float64

# %%
plt.bar(avg_stats_hp, )
#plt.legend(loc = "upper right")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-d5820986f973> in <module>
# ----> 1 plt.bar( avg_stats_hp)
#       2 #plt.legend(loc = "upper right")
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
#bar chart
avg_stats_type.index
# Out:
# Index(['aberration', 'beast', 'celestial', 'construct', 'dragon', 'elemental',
#        'fey', 'fiend', 'giant', 'humanoid', 'monstrosity', 'ooze', 'plant',
#        'swarm of Tiny beasts', 'undead'],
#       dtype='object', name='type')

# %%
stats_name = monster.groupby("name").sum()
stats_name
# Out:
#                         HP  Challenge Rating  intelligence  strength  wisdom  \
# name
# Aboleth                135             10.00            18        21      15
# Acolyte                  9              0.25            10        10      14
# Adult Black Dragon     195             14.00            14        23      13
# Adult Blue Dracolich   225             17.00            16        25      15
# Adult Blue Dragon      225             16.00            16        25      15
# Adult Brass Dragon     172             13.00            14        23      13
# Adult Bronze Dragon    212             15.00            16        25      15
# Adult Copper Dragon    184             14.00            18        23      15
# Adult Gold Dragon      256             17.00            16        27      15
# Adult Green Dragon     207             15.00            18        23      15
# Adult Red Dragon       256             17.00            16        27      13
# Adult Silver Dragon    243             16.00            16        27      13
# Adult White Dragon     200             13.00             8        22      12
# Air Elemental           90              5.00             6        14      10
# Ancient Black Dragon   367             21.00            16        27      15
# Ancient Blue Dragon    481             23.00            18        29      17
# Ancient Brass Dragon   297             20.00            16        27      15
# Ancient Bronze Dragon  444             22.00            18        29      17
# Ancient Copper Dragon  350             21.00            20        27      17
# Ancient Gold Dragon    546             24.00            18        30      17
# Ancient Green Dragon   385             22.00            20        27      17
# Ancient Red Dragon     546             24.00            18        30      15
# Ancient Silver Dragon  487             23.00            18        30      15
# Ancient White Dragon   333             20.00            10        26      13
# Androsphinx            199             17.00            16        22      18
# Animated Armor          33              1.00             1        14       3
# Ankheg                  39              2.00             1        17      13
# Ape                     19              0.50             6        16      12
# Archmage                99             12.00            20        10      15
# Assassin                78              8.00            13        11      11
# ...                    ...               ...           ...       ...     ...
# Vulture                  5              0.00             2         7      12
# Warhorse                19              0.50             2        18      12
# Warhorse Skeleton       22              0.50             2        18       8
# Water Elemental        114              5.00             5        18      10
# Weasel                   1              0.00             2         3      12
# Werebear               135              5.00            11        19      12
# Wereboar                78              4.00            10        17      11
# Wererat                 33              2.00            11        10      10
# Weretiger              120              4.00            10        17      13
# Werewolf                58              3.00            10        15      11
# White Dragon Wyrmling   32              2.00             5        14      10
# Wight                   45              3.00            10        15      13
# Will-o'-Wisp            22              2.00            13         1      14
# Winter Wolf             75              3.00             7        18      12
# Wolf                    11              0.25             3        12      12
# Worg                    26              0.50             7        16      11
# Wraith                  67              5.00            12         6      14
# Wyvern                 110              6.00             5        19      12
# Xorn                    73              5.00            11        17      10
# Young Black Dragon     127              7.00            12        19      11
# Young Blue Dragon      152              9.00            14        21      13
# Young Brass Dragon     110              6.00            12        19      11
# Young Bronze Dragon    142              8.00            14        21      13
# Young Copper Dragon    119              7.00            16        19      13
# Young Gold Dragon      178             10.00            16        23      13
# Young Green Dragon     136              8.00            16        19      13
# Young Red Dragon       178             10.00            14        23      11
# Young Silver Dragon    168              9.00            14        23      11
# Young White Dragon     133              6.00             6        18      11
# Zombie                  22              0.25             3        13       6
#
#                        dexterity
# name
# Aboleth                        9
# Acolyte                       10
# Adult Black Dragon            14
# Adult Blue Dracolich          10
# Adult Blue Dragon             10
# Adult Brass Dragon            10
# Adult Bronze Dragon           10
# Adult Copper Dragon           12
# Adult Gold Dragon             14
# Adult Green Dragon            12
# Adult Red Dragon              10
# Adult Silver Dragon           10
# Adult White Dragon            10
# Air Elemental                 20
# Ancient Black Dragon          14
# Ancient Blue Dragon           10
# Ancient Brass Dragon          10
# Ancient Bronze Dragon         10
# Ancient Copper Dragon         12
# Ancient Gold Dragon           14
# Ancient Green Dragon          12
# Ancient Red Dragon            10
# Ancient Silver Dragon         10
# Ancient White Dragon          10
# Androsphinx                   10
# Animated Armor                11
# Ankheg                        11
# Ape                           14
# Archmage                      14
# Assassin                      16
# ...                          ...
# Vulture                       10
# Warhorse                      12
# Warhorse Skeleton             12
# Water Elemental               14
# Weasel                        16
# Werebear                      10
# Wereboar                      10
# Wererat                       15
# Weretiger                     15
# Werewolf                      13
# White Dragon Wyrmling         10
# Wight                         14
# Will-o'-Wisp                  28
# Winter Wolf                   13
# Wolf                          15
# Worg                          13
# Wraith                        16
# Wyvern                        10
# Xorn                          10
# Young Black Dragon            14
# Young Blue Dragon             10
# Young Brass Dragon            10
# Young Bronze Dragon           10
# Young Copper Dragon           12
# Young Gold Dragon             14
# Young Green Dragon            12
# Young Red Dragon              10
# Young Silver Dragon           10
# Young White Dragon            10
# Zombie                         6
#
# [325 rows x 6 columns]

# %%
monster_size = monster.groupby("size")["name"].count()
monster_size
# Out:
# size
# Gargantuan     15
# Huge           33
# Large         105
# Medium        126
# Small          22
# Tiny           24
# Name: name, dtype: int64

# %%
labels=monster_size.index
labels
# Out:
# Index(['Gargantuan', 'Huge', 'Large', 'Medium', 'Small', 'Tiny'], dtype='object', name='size')

# %%
plt.pie(monster_size, labels=labels, autopct = "%1.2f%%")
#plt.legend(loc = "upper right")
plt.title("Monster Size")
plt.show()

# %%
type_str =monster.groupby("type")["strength"].mean()
type_str
# Out:
# type
# aberration              16.600000
# beast                   12.272727
# celestial               20.000000
# construct               16.666667
# dragon                  22.023256
# elemental               13.750000
# fey                     11.833333
# fiend                   16.652174
# giant                   22.500000
# humanoid                12.925000
# monstrosity             17.950000
# ooze                    14.250000
# plant                   11.166667
# swarm of Tiny beasts     5.600000
# undead                  13.000000
# Name: strength, dtype: float64

# %%
labels_str_type = type_cr.index
plt.pie(type_str, labels=labels_str_type, autopct = "%1.1f%%")
#plt.legend(loc = "upper right")
plt.show()

# %%
type_amount=monster.groupby("type")["name"].count()
type_amount
# Out:
# type
# aberration               5
# beast                   88
# celestial                6
# construct                9
# dragon                  43
# elemental               16
# fey                      6
# fiend                   23
# giant                   10
# humanoid                40
# monstrosity             40
# ooze                     4
# plant                    6
# swarm of Tiny beasts    10
# undead                  19
# Name: name, dtype: int64

# %%
plt.pie(type_amount, labels=labels_str_type, autopct = "%1.1f%%")
plt.axis("equal")
plt.show()

# %%
type_cr=monster.groupby("type")["Challenge Rating"].mean()
type_cr
# Out:
# type
# aberration               5.800000
# beast                    0.948864
# celestial                9.666667
# construct                5.583333
# dragon                  11.517442
# elemental                4.015625
# fey                      1.166667
# fiend                    8.228261
# giant                    6.900000
# humanoid                 1.971875
# monstrosity              5.850000
# ooze                     2.125000
# plant                    2.708333
# swarm of Tiny beasts     0.625000
# undead                   5.131579
# Name: Challenge Rating, dtype: float64

# %%
#Whisker Chart of Challenge Rating by Type
plt.title("Title")
plt.xlabel("x")
plt.ylabel("y")
plt.boxplot(type_cr)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x122dab978>,
#   <matplotlib.lines.Line2D at 0x122dabcc0>],
#  'caps': [<matplotlib.lines.Line2D at 0x122db3048>,
#   <matplotlib.lines.Line2D at 0x122db3390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x122dab828>],
#  'medians': [<matplotlib.lines.Line2D at 0x122db36d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x122db3a20>],
#  'means': []}

# %%
type_hp=monster.groupby("type")["HP"].mean()
type_hp
# Out:
# type
# aberration               97.400000
# beast                    25.545455
# celestial               133.666667
# construct                93.777778
# dragon                  202.139535
# elemental                77.562500
# fey                      35.166667
# fiend                   115.260870
# giant                   129.900000
# humanoid                 37.075000
# monstrosity             111.425000
# ooze                     59.000000
# plant                    62.333333
# swarm of Tiny beasts     24.400000
# undead                   64.473684
# Name: HP, dtype: float64

# %%
plt.title("Title")
plt.xlabel("x")
plt.ylabel("y")
plt.boxplot(type_hp)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1234de0f0>,
#   <matplotlib.lines.Line2D at 0x1234de438>],
#  'caps': [<matplotlib.lines.Line2D at 0x1234de780>,
#   <matplotlib.lines.Line2D at 0x1234deac8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1234d5f60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1234dee10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1234e7198>],
#  'means': []}

# %%
#Scatter of Challenge Rative and HP by Type
plt.title("Hit Points vs Challenge Rating")
plt.xlabel("Challenge Rating")
plt.ylabel("HP")
plt.scatter(type_cr, type_hp, color = ["green"])

# %%
size_smarts=monster.groupby("size")["intelligence"].mean()
size_smarts
# Out:
# size
# Gargantuan    14.066667
# Huge           9.575758
# Large          7.342857
# Medium         8.007937
# Small          5.227273
# Tiny           3.916667
# Name: intelligence, dtype: float64

# %%
height = [20, 16, 12, 8, 4]
plt.bar(size_smarts, height)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-f715925d9059> in <module>
#       1 height = [20, 16, 12, 8, 4]
# ----> 2 plt.bar(size_smarts, height)
#
# /anaconda3/envs/PythonData2/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# /anaconda3/envs/PythonData2/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/envs/PythonData2/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2249         x, height, width, y, linewidth = np.broadcast_arrays(
#    2250             # Make args iterable too.
# -> 2251             np.atleast_1d(x), height, width, y, linewidth)
#    2252
#    2253         # Now that units have been converted, set the tick locations.
#
# /anaconda3/envs/PythonData2/lib/python3.6/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     250     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     251
# --> 252     shape = _broadcast_shape(*args)
#     253
#     254     if all(array.shape == shape for array in args):
#
# /anaconda3/envs/PythonData2/lib/python3.6/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     185     # use the old-iterator because np.nditer does not handle size 0 arrays
#     186     # consistently
# --> 187     b = np.broadcast(*args[:32])
#     188     # unfortunately, it cannot handle 32 or more arguments directly
#     189     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
type_int = monster.groupby("type")["intelligence"].mean()
type_int
# Out:
# type
# aberration               9.000000
# beast                    2.386364
# celestial               16.666667
# construct                3.888889
# dragon                  13.906977
# elemental                9.187500
# fey                     12.500000
# fiend                   12.347826
# giant                    9.400000
# humanoid                10.650000
# monstrosity              6.600000
# ooze                     1.250000
# plant                    6.500000
# swarm of Tiny beasts     1.400000
# undead                   9.473684
# Name: intelligence, dtype: float64

# %%
type_wis = monster.groupby("type")["wisdom"].mean()
type_wis
# Out:
# type
# aberration              12.200000
# beast                   10.977273
# celestial               19.833333
# construct                7.888889
# dragon                  13.069767
# elemental               11.437500
# fey                     12.833333
# fiend                   13.434783
# giant                   11.700000
# humanoid                11.400000
# monstrosity             12.725000
# ooze                     6.000000
# plant                    8.666667
# swarm of Tiny beasts     8.600000
# undead                  11.105263
# Name: wisdom, dtype: float64

# %%
type_str = monster.groupby("type")["strength"].mean()
# Out:
# type
# aberration              16.600000
# beast                   12.272727
# celestial               20.000000
# construct               16.666667
# dragon                  22.023256
# elemental               13.750000
# fey                     11.833333
# fiend                   16.652174
# giant                   22.500000
# humanoid                12.925000
# monstrosity             17.950000
# ooze                    14.250000
# plant                   11.166667
# swarm of Tiny beasts     5.600000
# undead                  13.000000
# Name: strength, dtype: float64

# %%
plt.scatter(type_int, type_wis, s = type_str*10)

# %%
# %matplotlib inline
import requests
import json
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
from matplotlib import rcParams

base_url = "http://dnd5eapi.co/api/"

# %%
#found this fun plot style themes
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
#how to utilize
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## Monsters

# %%
monster_url = base_url + "monsters"
print(monster_url)
# Out:
# http://dnd5eapi.co/api/monsters

# %%
monster_names = requests.get(monster_url).json()
monster_names
# Out:
# {'count': 325,
#  'results': [{'name': 'Aboleth',
#    'url': 'http://www.dnd5eapi.co/api/monsters/1'},
#   {'name': 'Acolyte', 'url': 'http://www.dnd5eapi.co/api/monsters/2'},
#   {'name': 'Adult Black Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/3'},
#   {'name': 'Adult Blue Dracolich',
#    'url': 'http://www.dnd5eapi.co/api/monsters/4'},
#   {'name': 'Adult Blue Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/5'},
#   {'name': 'Adult Brass Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/6'},
#   {'name': 'Adult Bronze Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/7'},
#   {'name': 'Adult Copper Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/8'},
#   {'name': 'Adult Gold Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/9'},
#   {'name': 'Adult Green Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/10'},
#   {'name': 'Adult Red Dragon',
#    'url': 'http://www.dnd5eapi.co/api/monsters/11'},
# ...

# %%
#step through to get monster details
monster_details = []
monurl_list = []

for monster in monster_names["results"]:
    mon_url = monster["url"]
    monurl_list.append(mon_url)
    mon_dets = requests.get(mon_url).json()
    monster_details.append(mon_dets)
pprint(monster_details)
# Out:
# [{'_id': '5bce91465b7768e7920181a5',
#   'actions': [{'attack_bonus': 0,
#                'desc': 'The aboleth makes three tentacle attacks.',
#                'name': 'Multiattack'},
#               {'attack_bonus': 9,
#                'damage_bonus': 5,
#                'damage_dice': '2d6',
#                'desc': 'Melee Weapon Attack: +9 to hit, reach 10 ft., one '
#                        'target. Hit: 12 (2d6 + 5) bludgeoning damage. If the '
#                        'target is a creature, it must succeed on a DC 14 '
#                        'Constitution saving throw or become diseased. The '
#                        'disease has no effect for 1 minute and can be removed '
#                        'by any magic that cures disease. After 1 minute, the '
#                        "diseased creature's skin becomes translucent and "
#                        "slimy, the creature can't regain hit points unless it "
# ...

# %%
#pprint(monster_details[0]["name"])

Monsternames=[]
Monstersize = []
MonsterHP = []
MonsterIntelligence = []
MonsterDexterity = []
MonsterChallengeR = []
MonsterWisdom = []
MonsterStrength = []
MonsterType = []


for x in monster_details:
    monName = x["name"]
    Monsternames.append(monName)
    monSize = x["size"]
    Monstersize.append(monSize)
    monHP = x["hit_points"]
    MonsterHP.append(monHP)
    MonInt = x["intelligence"]
    MonsterIntelligence.append(MonInt)
    MonDex = x["dexterity"]
    MonsterDexterity.append(MonDex)
    MonChal = x["challenge_rating"]
    MonsterChallengeR.append(MonChal)
    MonStr = x["strength"]
    MonsterStrength.append(MonStr)
    MonWis = x["wisdom"]
    MonsterWisdom.append(MonWis)
    MonType = x["type"]
    MonsterType.append(MonType)
    
    
      
    
Monsternames

monster = pd.DataFrame()
monster["name"] = Monsternames
monster["type"] = MonsterType
monster["size"] = Monstersize
monster["HP"] = MonsterHP
monster["Challenge Rating"] = MonsterChallengeR
monster["intelligence"] = MonsterIntelligence
monster["strength"] = MonsterStrength
monster["wisdom"] = MonsterWisdom
monster["dexterity"] = MonsterDexterity


monster.head()
monster["type"].unique()
# Out:
# array(['aberration', 'humanoid', 'dragon', 'undead', 'elemental',
#        'monstrosity', 'construct', 'beast', 'plant', 'fiend', 'ooze',
#        'fey', 'giant', 'celestial', 'swarm of Tiny beasts'], dtype=object)

# %%
#group by avg stats
avg_stats_hp = monster.groupby("type")["HP"].mean().reset_index()
avg_stats_hp
# Out:
#                     type          HP
# 0             aberration   97.400000
# 1                  beast   25.545455
# 2              celestial  133.666667
# 3              construct   93.777778
# 4                 dragon  202.139535
# 5              elemental   77.562500
# 6                    fey   35.166667
# 7                  fiend  115.260870
# 8                  giant  129.900000
# 9               humanoid   37.075000
# 10           monstrosity  111.425000
# 11                  ooze   59.000000
# 12                 plant   62.333333
# 13  swarm of Tiny beasts   24.400000
# 14                undead   64.473684

# %%
plt.bar(avg_stats_hp["type"], avg_stats_hp["HP"], width = 0.5 )
plt.title("Avg. Hit Points by Type")
plt.ylabel("Hit Points")
plt.xticks(rotation="vertical")

rcParams.update({'figure.autolayout': True})
fig = plt.gcf()

#fig.set_size_inches(20,20)
plt.show()
fig.savefig('bar_hp_type.png')

# %%
stats_type = monster.groupby("type").sum()
stats_type
# Out:
#                         HP  Challenge Rating  intelligence  strength  wisdom  \
# type
# aberration             487            29.000            45        83      61
# beast                 2248            83.500           210      1080     966
# celestial              802            58.000           100       120     119
# construct              844            50.250            35       150      71
# dragon                8692           495.250           598       947     562
# elemental             1241            64.250           147       220     183
# fey                    211             7.000            75        71      77
# fiend                 2651           189.250           284       383     309
# giant                 1299            69.000            94       225     117
# humanoid              1483            78.875           426       517     456
# monstrosity           4457           234.000           264       718     509
# ...

# %%
monster_size = monster.groupby("size")["type"].count()
monster_size
# Out:
# size
# Gargantuan     15
# Huge           33
# Large         105
# Medium        126
# Small          22
# Tiny           24
# Name: type, dtype: int64

# %%
labels=monster_size.index
labels
# Out:
# Index(['Gargantuan', 'Huge', 'Large', 'Medium', 'Small', 'Tiny'], dtype='object', name='size')

# %%
plt.style.use("fivethirtyeight")
plt.pie(monster_size, labels=labels, autopct = "%1.2f%%")
#plt.legend(loc = "upper right")
plt.title("Monster Size", color = "blue")
fig = plt.gcf()
fig.set_size_inches(8,8)
plt.axis("equal")
plt.show()
fig.savefig('pie_monster_size.png')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
type_str =monster.groupby("type")["strength"].mean().reset_index()
type_str
# Out:
#                     type   strength
# 0             aberration  16.600000
# 1                  beast  12.272727
# 2              celestial  20.000000
# 3              construct  16.666667
# 4                 dragon  22.023256
# 5              elemental  13.750000
# 6                    fey  11.833333
# 7                  fiend  16.652174
# 8                  giant  22.500000
# 9               humanoid  12.925000
# 10           monstrosity  17.950000
# 11                  ooze  14.250000
# 12                 plant  11.166667
# 13  swarm of Tiny beasts   5.600000
# 14                undead  13.000000

# %%
rcParams.update({'figure.autolayout': True})

plt.bar(type_str["type"], type_str["strength"], width = 0.5)
plt.yticks(np.arange(min(type_str["strength"]), max(type_str["strength"])+1, 5.0))
plt.title("Avg. Strength by Type")
plt.ylabel("Strength")
plt.xticks(rotation="vertical")
fig = plt.gcf()
fig.set_size_inches(8, 5)
fig.savefig('bar_str_type.png')

# %%
type_amount=monster.groupby("type")["name"].count()
type_amount
# Out:
# type
# aberration               5
# beast                   88
# celestial                6
# construct                9
# dragon                  43
# elemental               16
# fey                      6
# fiend                   23
# giant                   10
# humanoid                40
# monstrosity             40
# ooze                     4
# plant                    6
# swarm of Tiny beasts    10
# undead                  19
# Name: name, dtype: int64

# %%
type_label=monster.groupby("type")["name"].count().index
type_label
# Out:
# Index(['aberration', 'beast', 'celestial', 'construct', 'dragon', 'elemental',
#        'fey', 'fiend', 'giant', 'humanoid', 'monstrosity', 'ooze', 'plant',
#        'swarm of Tiny beasts', 'undead'],
#       dtype='object', name='type')

# %%
plt.style.use("fivethirtyeight")
plt.pie(type_amount, labels=type_label, autopct = "%1.1f%%", shadow = True)
plt.axis("equal")
fig = plt.gcf()
fig.set_size_inches(8,9)
plt.title("Type of Monsters", loc = 'right', color = "Blue")
plt.show()
fig.savefig('pie_monster_type.png')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
type_cr=monster.groupby("type")["Challenge Rating"].mean()
type_cr
# Out:
# type
# aberration               5.800000
# beast                    0.948864
# celestial                9.666667
# construct                5.583333
# dragon                  11.517442
# elemental                4.015625
# fey                      1.166667
# fiend                    8.228261
# giant                    6.900000
# humanoid                 1.971875
# monstrosity              5.850000
# ooze                     2.125000
# plant                    2.708333
# swarm of Tiny beasts     0.625000
# undead                   5.131579
# Name: Challenge Rating, dtype: float64

# %%
type_hp=monster.groupby("type")["HP"].mean()
type_hp
# Out:
# type
# aberration               97.400000
# beast                    25.545455
# celestial               133.666667
# construct                93.777778
# dragon                  202.139535
# elemental                77.562500
# fey                      35.166667
# fiend                   115.260870
# giant                   129.900000
# humanoid                 37.075000
# monstrosity             111.425000
# ooze                     59.000000
# plant                    62.333333
# swarm of Tiny beasts     24.400000
# undead                   64.473684
# Name: HP, dtype: float64

# %%
type_str_scatter = monster.groupby("type")["strength"].mean()
type_str_scatter
# Out:
# type
# aberration              16.600000
# beast                   12.272727
# celestial               20.000000
# construct               16.666667
# dragon                  22.023256
# elemental               13.750000
# fey                     11.833333
# fiend                   16.652174
# giant                   22.500000
# humanoid                12.925000
# monstrosity             17.950000
# ooze                    14.250000
# plant                   11.166667
# swarm of Tiny beasts     5.600000
# undead                  13.000000
# Name: strength, dtype: float64

# %%
plt.style.use("fivethirtyeight")
#Scatter of Challenge Rative and HP by Type
plt.title("Hit Points vs Challenge Rating")
plt.xlabel("Challenge Rating")
plt.ylabel("HP")
plt.scatter(type_cr, type_hp,s = type_str_scatter*30, label = "INT",alpha = 0.5,  linewidth = 1.5)
type_list = avg_stats_hp["type"]
#adding +.2 in the code below shifts where the label appears on the graph. 
for i, txt in enumerate(type_list):
   plt.annotate(txt, xy=(type_cr[i]+.4, type_hp[i] +.4))
fig = plt.gcf()
fig.set_size_inches(9, 7)
fig.savefig('scatter_hp_cr.png')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
type_int = monster.groupby("type")["intelligence"].mean()
type_int
# Out:
# type
# aberration               9.000000
# beast                    2.386364
# celestial               16.666667
# construct                3.888889
# dragon                  13.906977
# elemental                9.187500
# fey                     12.500000
# fiend                   12.347826
# giant                    9.400000
# humanoid                10.650000
# monstrosity              6.600000
# ooze                     1.250000
# plant                    6.500000
# swarm of Tiny beasts     1.400000
# undead                   9.473684
# Name: intelligence, dtype: float64

# %%
type_wis = monster.groupby("type")["wisdom"].mean()
type_wis
# Out:
# type
# aberration              12.200000
# beast                   10.977273
# celestial               19.833333
# construct                7.888889
# dragon                  13.069767
# elemental               11.437500
# fey                     12.833333
# fiend                   13.434783
# giant                   11.700000
# humanoid                11.400000
# monstrosity             12.725000
# ooze                     6.000000
# plant                    8.666667
# swarm of Tiny beasts     8.600000
# undead                  11.105263
# Name: wisdom, dtype: float64

# %%
type_str_scatter = monster.groupby("type")["strength"].mean()
type_str_scatter
# Out:
# type
# aberration              16.600000
# beast                   12.272727
# celestial               20.000000
# construct               16.666667
# dragon                  22.023256
# elemental               13.750000
# fey                     11.833333
# fiend                   16.652174
# giant                   22.500000
# humanoid                12.925000
# monstrosity             17.950000
# ooze                    14.250000
# plant                   11.166667
# swarm of Tiny beasts     5.600000
# undead                  13.000000
# Name: strength, dtype: float64

# %%
plt.style.use("fivethirtyeight")
plt.scatter(type_int, type_wis, s = type_str_scatter*30, label = "Strength",alpha = 0.6,  linewidth = 1.5)
type_list = avg_stats_hp["type"]
#adding +.2 in the code below shifts where the label appears on the graph.  Depending on the final size of the graph, you may need to shift

for i, txt in enumerate(type_list):
   plt.annotate(txt, xy=(type_int[i]+.2, type_wis[i] +.2))
plt.title("Intelligence vs. Wisdom")
plt.xlabel("Intelligence")
plt.ylabel("Wisdom")
plt.legend(loc= "lower right")
fig = plt.gcf()
fig.set_size_inches(9, 7)
plt.show()
fig.savefig('scatter_int_wis.png')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
